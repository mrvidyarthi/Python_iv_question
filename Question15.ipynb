# %%
year = 2000
if (year%4 == 0 and year%100 != 0) or year%400 == 0:
    print(f"{year} is a leep year.")
else:
    print(f"{year} is not a leep year.")
# Out:
# 2000 is a leep year.

# %%
def leep_year_checker(year: int) -> bool:
    if not isinstance(year,int):
        raise TypeError("Input must be an integer.")
    if year <= 1582 or year > 10000:
        raise("Out of range enter year please enter between 1581 to 10000")
    leep_year = False
    if (year%4 == 0 and year%100 != 0) or year%400 == 0:
        return True
    else:
        return False

# %%
print(leep_year_checker(1444))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(leep_year_checker(1444))
#
# Cell In[10], line 5, in leep_year_checker(year)
#       3     raise TypeError("Input must be an integer.")
#       4 if year <= 1582 or year > 10000:
# ----> 5     raise("Out of range enter year please enter between 1581 to 10000")
#       6 leep_year = False
#       7 if (year%4 == 0 and year%100 != 0) or year%400 == 0:
#
# TypeError: exceptions must derive from BaseException

# %%
def leep_year_checker(year: int) -> bool:
    """
    This function can check that enter year is leep year or not
    Args:
        year(int): Accept only 4 digit int type year
    Returns:
        Leep_year(bool): Return true if year is leep year otherwise false
    """
    if not isinstance(year,int):
        raise TypeError("Input must be an integer.")
    if year <= 1582 or year > 10000:
        raise ValueError("Out of range enter year please enter between 1581 to 10000")
    leep_year = False
    if (year%4 == 0 and year%100 != 0) or year%400 == 0:
        return True
    else:
        return False
if __name__ == "__main__" :
    user = input("Input your year: ")
    try:
        if not user.isdigit():
            raise TypeError("Input only numeric value")
        user = int(user)
        result = leep_year_checker(user)
        
        if result:
            print(f"{user} is a leep year.")
        else:
            print(f"{user} is not a leep year.")
    except (TypeError,ValueError,Exception) as e:
        print(e)
# Out:
# Out of range enter year please enter between 1581 to 10000
