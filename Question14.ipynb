# %%
def fibonacci(num: int) -> list:
    
    a = 0
    b = 1
    result = []          
    
    for i in range(num):
        result.append(a)  
        a, b = b, a + b   
        
    return result


print(fibonacci(5))
# Out:
# [0, 1, 1, 2, 3]
