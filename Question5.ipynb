# %%
num = int(input("Enter a number: "))
fact = 1
for i in range(1,num+1):
    fact = fact * i
print("Factorial = ",fact)
# Out:
# Enter a number:  5
# Factorial =  120

# %%
def factorial(num : int) -> int:
    if not isinstance(num, int):
        raise TypeError("Input must be an integer.")
    if num < 0:
        raise ValueError("Factorial number is not valid for negative number.")
    if isinstance(num, bool):
        raise TypeError("Boolean are not allowed in this function.")
    fact = 1
    for i in range(1,num+1):
        fact = fact * i

    return fact

# %%
factorial(-12)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 factorial(-12)
#
# Cell In[24], line 23, in factorial(num)
#      20     raise TypeError("Boolean are not allowed in this function.")
#      22 if num < 0:
# ---> 23     raise ValueError("Factorial number is not valid for negative number.")
#      25 fact = 1
#      26 for i in range(1,num+1):
#
# ValueError: Factorial number is not valid for negative number.

# %%
def factorial(num : int) -> int:
    """
    This function is find the factorial of given input
    Args:
        This fucntion is accept integer value.
    Returns:
        This function is return the Factorial of given number.
    Raise:
        TypeError:
            If you are not insert the integer type value in this function.
            If you are insert the Boolean value.
        ValueError:
            If number is less then 0.
    """
    
    if not isinstance(num, int):
        raise TypeError("Input must be an integer.")
        
    if isinstance(num, bool):
        raise TypeError("Boolean are not allowed in this function.")

    if num < 0:
        raise ValueError("Factorial number is not valid for negative number.")
        
    fact = 1
    for i in range(1,num+1):
        fact = fact * i

    return fact

if __name__ == "__main__":
    try : 
        user = input("Enter any number: ")
        if not user.strip().isdigit():
            raise ValueError("Input only the ineger number.")
        number = int(user)
        # calling funciton 
        result = factorial(number)
        print(f"Factorial of {number} is : {result}")
    except (TypeError,ValueError,Exception) as e :
        print(e)
# Out:
# Enter any number:  -19
# Input only the ineger number.

# %%
try : 
        user = input("Enter any number: ")
        if not user.strip().isdigit():
            raise ValueError("Input only the ineger number.")
        number = int(user)
        # calling funciton 
        result = factorial(number)
        print(f"Factorial of {number} is : {result}")
    except (TypeError,ValueError,Exception) as e :
        print(e)
